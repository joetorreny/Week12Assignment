# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests,json,pprint
# %matplotlib inline
from pandas.io.json import json_normalize

# %% [markdown]
# Loading API data and trasforming it into pandas dataframe

# %%
df = pd.read_json('https://api.nytimes.com/svc/movies/v2/reviews/search.json?api-key=9d97495c429c41beb7c3225695e471bd')
df2 = json_normalize(df['results'])
df2.head()
# Out:
#                 byline  critics_pick         date_updated    display_title  \
# 0       MANOHLA DARGIS             0  2017-11-15 14:48:03   Justice League
# 1       BEN KENIGSBERG             0  2017-11-14 18:42:03  Song of Granite
# 2      MONICA CASTILLO             1  2017-11-15 03:44:31   Santa & Andrés
# 3         ANDY WEBSTER             1  2017-11-09 12:04:03   I Remember You
# 4  JEANNETTE CATSOULIS             1  2017-11-15 03:44:29            Bitch
#
#                                             headline  \
# 0  Review: ‘Justice League,’ Better Than the Last...
# 1  Review: In ‘Song of Granite,’ Fragments of an ...
# 2  Review: ‘Santa & Andrés’ Chooses Friendship Ov...
# 3  Review: ‘I Remember You’ Is a Piercing Horror ...
# 4  Review: In ‘Bitch,’ a Desperate Housewife Find...
#
#                             link.suggested_link_text link.type  \
# 0   Read the New York Times Review of Justice League   article
# 1  Read the New York Times Review of Song of Granite   article
# ...
